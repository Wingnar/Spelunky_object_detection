# %% [markdown]
# # **Instructions**:
#
# ### 1 - Open your game that you want to perform detections
# ### 2 - In the game window, get the name of it's title bar
# ### 3 - Update the variable "window_name" with the game title bar name
# ### 4 - Run all cells to start detecting objects using your trained model

# %%
import numpy as np
import win32gui, win32ui, win32con
from PIL import Image
from time import sleep
import cv2 as cv
import os
import random

# %%
class WindowCapture:
    w = 0
    h = 0
    hwnd = None

    def __init__(self, window_name):
        self.hwnd = win32gui.FindWindow(None, window_name)
        if not self.hwnd:
            raise Exception('Window not found: {}'.format(window_name))

        window_rect = win32gui.GetWindowRect(self.hwnd)
        self.w = window_rect[2] - window_rect[0]
        self.h = window_rect[3] - window_rect[1]

        border_pixels = 8
        titlebar_pixels = 30
        self.w = self.w - (border_pixels * 2)
        self.h = self.h - titlebar_pixels - border_pixels
        self.cropped_x = border_pixels
        self.cropped_y = titlebar_pixels

    def get_screenshot(self):
        wDC = win32gui.GetWindowDC(self.hwnd)
        dcObj = win32ui.CreateDCFromHandle(wDC)
        cDC = dcObj.CreateCompatibleDC()
        dataBitMap = win32ui.CreateBitmap()
        dataBitMap.CreateCompatibleBitmap(dcObj, self.w, self.h)
        cDC.SelectObject(dataBitMap)
        cDC.BitBlt((0, 0), (self.w, self.h), dcObj, (self.cropped_x, self.cropped_y), win32con.SRCCOPY)

        signedIntsArray = dataBitMap.GetBitmapBits(True)
        img = np.fromstring(signedIntsArray, dtype='uint8')
        img.shape = (self.h, self.w, 4)

        dcObj.DeleteDC()
        cDC.DeleteDC()
        win32gui.ReleaseDC(self.hwnd, wDC)
        win32gui.DeleteObject(dataBitMap.GetHandle())

        img = img[...,:3]
        img = np.ascontiguousarray(img) 
            
        return img

    def generate_image_dataset(self):
        if not os.path.exists("images"):
            os.mkdir("images")
        while(True):
            img = self.get_screenshot()
            im = Image.fromarray(img[..., [2, 1, 0]])
            im.save(f"./images/img_{len(os.listdir('images'))}.jpeg")
            sleep(1)
    
    def get_window_size(self):
        return (self.w, self.h)

# %%
class ImageProcessor:
    W = 0
    H = 0
    net = None
    ln = None
    classes = {}
    colors = []

    def __init__(self, img_size, cfg_file, weights_file):
        np.random.seed(42)
        self.net = cv.dnn.readNetFromDarknet(cfg_file, weights_file)
        self.net.setPreferableBackend(cv.dnn.DNN_BACKEND_OPENCV)
        self.ln = self.net.getLayerNames()
        self.ln = [self.ln[i-1] for i in self.net.getUnconnectedOutLayers()]
        self.W = img_size[0]
        self.H = img_size[1]
        
        with open('yolov4-tiny/obj.names', 'r') as file:
            lines = file.readlines()
        for i, line in enumerate(lines):
            self.classes[i] = line.strip()
        
        # If you plan to utilize more than six classes, please include additional colors in this list.
        self.colors = [
            (0, 0, 255), 
            (0, 255, 0), 
            (255, 0, 0), 
            (255, 255, 0), 
            (255, 0, 255), 
            (0, 255, 255)
        ]
        

    def proccess_image(self, img):

        blob = cv.dnn.blobFromImage(img, 1/255.0, (416, 416), swapRB=True, crop=False)
        self.net.setInput(blob)
        outputs = self.net.forward(self.ln)
        outputs = np.vstack(outputs)
        
        coordinates = self.get_coordinates(outputs, 0.5)

        self.draw_identified_objects(img, coordinates)

        return coordinates

    def get_coordinates(self, outputs, conf):

        boxes = []
        confidences = []
        classIDs = []

        for output in outputs:
            scores = output[5:]
            
            classID = np.argmax(scores)
            confidence = scores[classID]
            if confidence > conf:
                x, y, w, h = output[:4] * np.array([self.W, self.H, self.W, self.H])
                p0 = int(x - w//2), int(y - h//2)
                boxes.append([*p0, int(w), int(h)])
                confidences.append(float(confidence))
                classIDs.append(classID)

        indices = cv.dnn.NMSBoxes(boxes, confidences, conf, conf-0.1)

        if len(indices) == 0:
            return []

        coordinates = []
        for i in indices.flatten():
            (x, y) = (boxes[i][0], boxes[i][1])
            (w, h) = (boxes[i][2], boxes[i][3])

            coordinates.append({'x': x, 'y': y, 'w': w, 'h': h, 'class': classIDs[i], 'class_name': self.classes[classIDs[i]]})
        return coordinates

    def draw_identified_objects(self, img, coordinates):
        for coordinate in coordinates:
            x = coordinate['x']
            y = coordinate['y']
            w = coordinate['w']
            h = coordinate['h']
            classID = coordinate['class']
            
            color = self.colors[classID]
            
            cv.rectangle(img, (x, y), (x + w, y + h), color, 2)
            cv.putText(img, self.classes[classID], (x, y - 10), cv.FONT_HERSHEY_SIMPLEX, 0.5, color, 2)
        cv.imshow('window',  img)

# %%
# Run this cell to initiate detections using the trained model.

window_name = "Spelunky"
cfg_file_name = "./yolov4-tiny/yolov4-tiny-custom.cfg"
weights_file_name = "yolov4-tiny-custom_last.weights"

wincap = WindowCapture(window_name)
improc = ImageProcessor(wincap.get_window_size(), cfg_file_name, weights_file_name)

while(True):
    
    ss = wincap.get_screenshot()
    
    if cv.waitKey(1) == ord('q'):
        cv.destroyAllWindows()
        break

    coordinates = improc.proccess_image(ss)
    
    for coordinate in coordinates:
        print(coordinate)
    print()
    
    # If you have limited computer resources, consider adding a sleep delay between detections.
    # sleep(0.2)

print('Finished.')
# Out:
# C:\Users\ofsaa\AppData\Local\Temp\ipykernel_6964\2781964491.py:32: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   img = np.fromstring(signedIntsArray, dtype='uint8')
# {'x': 1057, 'y': 474, 'w': 96, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1057, 'y': 474, 'w': 96, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1057, 'y': 474, 'w': 96, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1057, 'y': 474, 'w': 96, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1057, 'y': 474, 'w': 96, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1057, 'y': 474, 'w': 96, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1057, 'y': 474, 'w': 96, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1057, 'y': 474, 'w': 96, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1057, 'y': 474, 'w': 96, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1057, 'y': 474, 'w': 96, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1057, 'y': 474, 'w': 96, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1057, 'y': 474, 'w': 96, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1057, 'y': 474, 'w': 96, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1057, 'y': 474, 'w': 96, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1057, 'y': 474, 'w': 96, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1057, 'y': 474, 'w': 96, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1057, 'y': 474, 'w': 96, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1057, 'y': 474, 'w': 96, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1057, 'y': 474, 'w': 96, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1057, 'y': 474, 'w': 96, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1057, 'y': 474, 'w': 96, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1057, 'y': 474, 'w': 96, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1057, 'y': 474, 'w': 96, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1057, 'y': 474, 'w': 96, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1057, 'y': 474, 'w': 96, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1057, 'y': 474, 'w': 96, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1057, 'y': 474, 'w': 96, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1057, 'y': 474, 'w': 96, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1057, 'y': 474, 'w': 96, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1057, 'y': 474, 'w': 96, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1057, 'y': 474, 'w': 96, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1057, 'y': 474, 'w': 96, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1057, 'y': 474, 'w': 96, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1057, 'y': 474, 'w': 96, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1057, 'y': 474, 'w': 96, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1057, 'y': 474, 'w': 96, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1057, 'y': 474, 'w': 96, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1057, 'y': 474, 'w': 96, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1057, 'y': 474, 'w': 96, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1057, 'y': 474, 'w': 96, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1057, 'y': 474, 'w': 96, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1057, 'y': 474, 'w': 96, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1057, 'y': 474, 'w': 96, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1057, 'y': 474, 'w': 96, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1057, 'y': 474, 'w': 96, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1057, 'y': 474, 'w': 96, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1057, 'y': 474, 'w': 96, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1057, 'y': 474, 'w': 96, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1057, 'y': 474, 'w': 96, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1057, 'y': 474, 'w': 96, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1057, 'y': 474, 'w': 96, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1057, 'y': 474, 'w': 96, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1057, 'y': 474, 'w': 96, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1057, 'y': 474, 'w': 96, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1057, 'y': 474, 'w': 96, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1057, 'y': 474, 'w': 96, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1057, 'y': 474, 'w': 96, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1057, 'y': 474, 'w': 96, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1057, 'y': 474, 'w': 96, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1057, 'y': 474, 'w': 96, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1057, 'y': 474, 'w': 96, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1057, 'y': 474, 'w': 96, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1057, 'y': 474, 'w': 96, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1057, 'y': 474, 'w': 96, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1057, 'y': 474, 'w': 96, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1057, 'y': 474, 'w': 96, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1057, 'y': 474, 'w': 96, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1057, 'y': 474, 'w': 96, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1057, 'y': 474, 'w': 96, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1057, 'y': 474, 'w': 96, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1057, 'y': 474, 'w': 96, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1057, 'y': 474, 'w': 96, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1057, 'y': 474, 'w': 96, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1057, 'y': 474, 'w': 96, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1057, 'y': 474, 'w': 96, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1057, 'y': 474, 'w': 96, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1057, 'y': 474, 'w': 96, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1057, 'y': 474, 'w': 96, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1057, 'y': 474, 'w': 96, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1057, 'y': 474, 'w': 96, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1057, 'y': 474, 'w': 96, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1057, 'y': 474, 'w': 96, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1057, 'y': 474, 'w': 96, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1057, 'y': 474, 'w': 96, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1057, 'y': 474, 'w': 96, 'h': 111, 'class': 3, 'class_name': 'You'}
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1056, 'y': 474, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
#
#
#
#
#
#
#
#
#
#
#
# {'x': 1057, 'y': 474, 'w': 96, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1057, 'y': 474, 'w': 96, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1057, 'y': 474, 'w': 96, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1057, 'y': 474, 'w': 96, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 1051, 'y': 472, 'w': 99, 'h': 110, 'class': 3, 'class_name': 'You'}
#
# {'x': 1024, 'y': 470, 'w': 98, 'h': 114, 'class': 3, 'class_name': 'You'}
#
# {'x': 1004, 'y': 470, 'w': 92, 'h': 115, 'class': 3, 'class_name': 'You'}
#
# {'x': 978, 'y': 473, 'w': 98, 'h': 109, 'class': 3, 'class_name': 'You'}
#
# {'x': 961, 'y': 472, 'w': 99, 'h': 110, 'class': 3, 'class_name': 'You'}
#
# {'x': 942, 'y': 472, 'w': 94, 'h': 113, 'class': 3, 'class_name': 'You'}
#
# {'x': 921, 'y': 470, 'w': 90, 'h': 106, 'class': 3, 'class_name': 'You'}
#
# {'x': 895, 'y': 474, 'w': 99, 'h': 109, 'class': 3, 'class_name': 'You'}
#
# {'x': 894, 'y': 471, 'w': 83, 'h': 104, 'class': 3, 'class_name': 'You'}
#
# {'x': 881, 'y': 475, 'w': 87, 'h': 105, 'class': 3, 'class_name': 'You'}
#
# {'x': 878, 'y': 474, 'w': 87, 'h': 105, 'class': 3, 'class_name': 'You'}
#
# {'x': 878, 'y': 475, 'w': 85, 'h': 103, 'class': 3, 'class_name': 'You'}
#
# {'x': 886, 'y': 472, 'w': 85, 'h': 102, 'class': 3, 'class_name': 'You'}
#
# {'x': 887, 'y': 471, 'w': 90, 'h': 104, 'class': 3, 'class_name': 'You'}
#
# {'x': 889, 'y': 474, 'w': 93, 'h': 107, 'class': 3, 'class_name': 'You'}
#
# {'x': 897, 'y': 475, 'w': 89, 'h': 106, 'class': 3, 'class_name': 'You'}
#
# {'x': 902, 'y': 475, 'w': 86, 'h': 109, 'class': 3, 'class_name': 'You'}
#
# {'x': 916, 'y': 474, 'w': 82, 'h': 99, 'class': 3, 'class_name': 'You'}
#
# {'x': 921, 'y': 473, 'w': 81, 'h': 101, 'class': 3, 'class_name': 'You'}
#
# {'x': 915, 'y': 475, 'w': 90, 'h': 102, 'class': 3, 'class_name': 'You'}
#
# {'x': 926, 'y': 471, 'w': 81, 'h': 104, 'class': 3, 'class_name': 'You'}
#
# {'x': 930, 'y': 473, 'w': 81, 'h': 101, 'class': 3, 'class_name': 'You'}
#
# {'x': 936, 'y': 476, 'w': 85, 'h': 101, 'class': 3, 'class_name': 'You'}
#
# {'x': 946, 'y': 471, 'w': 87, 'h': 105, 'class': 3, 'class_name': 'You'}
#
# {'x': 949, 'y': 469, 'w': 86, 'h': 107, 'class': 3, 'class_name': 'You'}
#
# {'x': 951, 'y': 467, 'w': 87, 'h': 112, 'class': 3, 'class_name': 'You'}
#
# {'x': 952, 'y': 468, 'w': 84, 'h': 110, 'class': 3, 'class_name': 'You'}
#
# {'x': 960, 'y': 473, 'w': 97, 'h': 109, 'class': 3, 'class_name': 'You'}
#
# {'x': 975, 'y': 471, 'w': 100, 'h': 113, 'class': 3, 'class_name': 'You'}
#
# {'x': 996, 'y': 472, 'w': 100, 'h': 113, 'class': 3, 'class_name': 'You'}
#
# {'x': 1023, 'y': 466, 'w': 92, 'h': 115, 'class': 3, 'class_name': 'You'}
#
# {'x': 1053, 'y': 469, 'w': 97, 'h': 116, 'class': 3, 'class_name': 'You'}
#
# {'x': 1069, 'y': 469, 'w': 98, 'h': 117, 'class': 3, 'class_name': 'You'}
#
# {'x': 1090, 'y': 468, 'w': 104, 'h': 118, 'class': 3, 'class_name': 'You'}
#
# {'x': 1114, 'y': 468, 'w': 101, 'h': 118, 'class': 3, 'class_name': 'You'}
#
# {'x': 1139, 'y': 469, 'w': 100, 'h': 116, 'class': 3, 'class_name': 'You'}
#
# {'x': 1163, 'y': 462, 'w': 94, 'h': 119, 'class': 3, 'class_name': 'You'}
#
# {'x': 1184, 'y': 466, 'w': 100, 'h': 112, 'class': 3, 'class_name': 'You'}
#
# {'x': 1204, 'y': 468, 'w': 97, 'h': 118, 'class': 3, 'class_name': 'You'}
#
# {'x': 1233, 'y': 467, 'w': 94, 'h': 120, 'class': 3, 'class_name': 'You'}
#
# {'x': 1255, 'y': 466, 'w': 91, 'h': 115, 'class': 3, 'class_name': 'You'}
#
# {'x': 1278, 'y': 472, 'w': 92, 'h': 110, 'class': 3, 'class_name': 'You'}
#
# {'x': 1298, 'y': 466, 'w': 95, 'h': 115, 'class': 3, 'class_name': 'You'}
#
# {'x': 1324, 'y': 471, 'w': 95, 'h': 114, 'class': 3, 'class_name': 'You'}
#
# {'x': 1349, 'y': 473, 'w': 92, 'h': 110, 'class': 3, 'class_name': 'You'}
#
# {'x': 1369, 'y': 475, 'w': 93, 'h': 105, 'class': 3, 'class_name': 'You'}
#
# {'x': 1392, 'y': 470, 'w': 87, 'h': 106, 'class': 3, 'class_name': 'You'}
#
# {'x': 1413, 'y': 471, 'w': 92, 'h': 105, 'class': 3, 'class_name': 'You'}
#
# {'x': 1436, 'y': 470, 'w': 90, 'h': 102, 'class': 3, 'class_name': 'You'}
#
# {'x': 1452, 'y': 468, 'w': 75, 'h': 109, 'class': 3, 'class_name': 'You'}
#
# {'x': 1486, 'y': 466, 'w': 39, 'h': 108, 'class': 3, 'class_name': 'You'}
#
#
#
#
#
# {'x': 1258, 'y': 824, 'w': 97, 'h': 29, 'class': 3, 'class_name': 'You'}
#
#
# {'x': 933, 'y': 750, 'w': 63, 'h': 84, 'class': 1, 'class_name': 'Snake'}
# {'x': 1264, 'y': 736, 'w': 72, 'h': 61, 'class': 2, 'class_name': 'Spider'}
# {'x': 1367, 'y': 729, 'w': 59, 'h': 67, 'class': 2, 'class_name': 'Spider'}
#
# {'x': 931, 'y': 722, 'w': 62, 'h': 87, 'class': 1, 'class_name': 'Snake'}
# {'x': 1265, 'y': 707, 'w': 69, 'h': 68, 'class': 3, 'class_name': 'You'}
# {'x': 1363, 'y': 702, 'w': 60, 'h': 72, 'class': 3, 'class_name': 'You'}
#
# {'x': 922, 'y': 709, 'w': 64, 'h': 81, 'class': 1, 'class_name': 'Snake'}
# {'x': 1266, 'y': 697, 'w': 68, 'h': 57, 'class': 2, 'class_name': 'Spider'}
#
# {'x': 922, 'y': 700, 'w': 66, 'h': 80, 'class': 1, 'class_name': 'Snake'}
# {'x': 1266, 'y': 686, 'w': 67, 'h': 57, 'class': 2, 'class_name': 'Spider'}
# {'x': 1484, 'y': 487, 'w': 40, 'h': 96, 'class': 3, 'class_name': 'You'}
# {'x': 1365, 'y': 679, 'w': 65, 'h': 63, 'class': 2, 'class_name': 'Spider'}
#
# {'x': 1467, 'y': 488, 'w': 61, 'h': 94, 'class': 3, 'class_name': 'You'}
# {'x': 921, 'y': 696, 'w': 67, 'h': 79, 'class': 1, 'class_name': 'Snake'}
# {'x': 1364, 'y': 674, 'w': 57, 'h': 66, 'class': 3, 'class_name': 'You'}
# {'x': 1263, 'y': 679, 'w': 69, 'h': 63, 'class': 3, 'class_name': 'You'}
#
# {'x': 1446, 'y': 485, 'w': 79, 'h': 89, 'class': 3, 'class_name': 'You'}
# {'x': 928, 'y': 691, 'w': 63, 'h': 83, 'class': 1, 'class_name': 'Snake'}
# {'x': 1364, 'y': 673, 'w': 62, 'h': 65, 'class': 2, 'class_name': 'Spider'}
# {'x': 1263, 'y': 675, 'w': 72, 'h': 63, 'class': 3, 'class_name': 'You'}
#
# {'x': 1412, 'y': 479, 'w': 104, 'h': 99, 'class': 3, 'class_name': 'You'}
# {'x': 929, 'y': 689, 'w': 62, 'h': 83, 'class': 1, 'class_name': 'Snake'}
# {'x': 1361, 'y': 671, 'w': 67, 'h': 64, 'class': 2, 'class_name': 'Spider'}
# {'x': 1263, 'y': 673, 'w': 74, 'h': 64, 'class': 3, 'class_name': 'You'}
#
# {'x': 1398, 'y': 474, 'w': 101, 'h': 110, 'class': 3, 'class_name': 'You'}
# {'x': 929, 'y': 690, 'w': 63, 'h': 82, 'class': 1, 'class_name': 'Snake'}
# {'x': 1361, 'y': 671, 'w': 66, 'h': 64, 'class': 2, 'class_name': 'Spider'}
# {'x': 1263, 'y': 673, 'w': 74, 'h': 64, 'class': 2, 'class_name': 'Spider'}
#
# {'x': 1371, 'y': 475, 'w': 92, 'h': 106, 'class': 3, 'class_name': 'You'}
# {'x': 928, 'y': 689, 'w': 67, 'h': 85, 'class': 1, 'class_name': 'Snake'}
# {'x': 1362, 'y': 672, 'w': 65, 'h': 63, 'class': 2, 'class_name': 'Spider'}
# {'x': 1264, 'y': 673, 'w': 73, 'h': 64, 'class': 2, 'class_name': 'Spider'}
#
# {'x': 1347, 'y': 475, 'w': 95, 'h': 105, 'class': 3, 'class_name': 'You'}
# {'x': 931, 'y': 687, 'w': 65, 'h': 87, 'class': 1, 'class_name': 'Snake'}
# {'x': 1362, 'y': 672, 'w': 65, 'h': 63, 'class': 2, 'class_name': 'Spider'}
# {'x': 1263, 'y': 673, 'w': 72, 'h': 64, 'class': 2, 'class_name': 'Spider'}
#
# {'x': 1318, 'y': 475, 'w': 98, 'h': 104, 'class': 3, 'class_name': 'You'}
# {'x': 931, 'y': 687, 'w': 65, 'h': 87, 'class': 1, 'class_name': 'Snake'}
# {'x': 1362, 'y': 672, 'w': 65, 'h': 63, 'class': 2, 'class_name': 'Spider'}
# {'x': 1263, 'y': 674, 'w': 72, 'h': 63, 'class': 3, 'class_name': 'You'}
#
# {'x': 1294, 'y': 476, 'w': 103, 'h': 104, 'class': 3, 'class_name': 'You'}
# {'x': 1363, 'y': 672, 'w': 64, 'h': 63, 'class': 2, 'class_name': 'Spider'}
# {'x': 926, 'y': 691, 'w': 67, 'h': 79, 'class': 1, 'class_name': 'Snake'}
# {'x': 1264, 'y': 674, 'w': 72, 'h': 63, 'class': 2, 'class_name': 'Spider'}
#
# {'x': 1277, 'y': 476, 'w': 96, 'h': 102, 'class': 3, 'class_name': 'You'}
# {'x': 1363, 'y': 672, 'w': 64, 'h': 63, 'class': 2, 'class_name': 'Spider'}
# {'x': 922, 'y': 689, 'w': 68, 'h': 80, 'class': 1, 'class_name': 'Snake'}
# {'x': 1264, 'y': 673, 'w': 72, 'h': 64, 'class': 3, 'class_name': 'You'}
#
# {'x': 1255, 'y': 478, 'w': 95, 'h': 105, 'class': 3, 'class_name': 'You'}
# {'x': 1361, 'y': 672, 'w': 67, 'h': 63, 'class': 2, 'class_name': 'Spider'}
# {'x': 922, 'y': 689, 'w': 68, 'h': 80, 'class': 1, 'class_name': 'Snake'}
# {'x': 1264, 'y': 673, 'w': 73, 'h': 64, 'class': 3, 'class_name': 'You'}
#
# {'x': 1249, 'y': 478, 'w': 95, 'h': 103, 'class': 3, 'class_name': 'You'}
# {'x': 1361, 'y': 672, 'w': 67, 'h': 63, 'class': 2, 'class_name': 'Spider'}
# {'x': 924, 'y': 691, 'w': 68, 'h': 78, 'class': 1, 'class_name': 'Snake'}
# {'x': 1264, 'y': 672, 'w': 73, 'h': 64, 'class': 3, 'class_name': 'You'}
#
# {'x': 1249, 'y': 478, 'w': 94, 'h': 103, 'class': 3, 'class_name': 'You'}
# {'x': 929, 'y': 689, 'w': 62, 'h': 83, 'class': 1, 'class_name': 'Snake'}
# {'x': 1361, 'y': 672, 'w': 67, 'h': 63, 'class': 2, 'class_name': 'Spider'}
# {'x': 1263, 'y': 672, 'w': 73, 'h': 64, 'class': 3, 'class_name': 'You'}
#
# {'x': 1249, 'y': 478, 'w': 95, 'h': 103, 'class': 3, 'class_name': 'You'}
# {'x': 929, 'y': 689, 'w': 62, 'h': 83, 'class': 1, 'class_name': 'Snake'}
# {'x': 1361, 'y': 672, 'w': 67, 'h': 63, 'class': 2, 'class_name': 'Spider'}
# {'x': 1263, 'y': 673, 'w': 73, 'h': 64, 'class': 3, 'class_name': 'You'}
#
# {'x': 1249, 'y': 478, 'w': 95, 'h': 103, 'class': 3, 'class_name': 'You'}
# {'x': 929, 'y': 690, 'w': 63, 'h': 83, 'class': 1, 'class_name': 'Snake'}
# {'x': 1361, 'y': 672, 'w': 67, 'h': 63, 'class': 2, 'class_name': 'Spider'}
# {'x': 1264, 'y': 673, 'w': 73, 'h': 64, 'class': 3, 'class_name': 'You'}
#
# {'x': 1249, 'y': 478, 'w': 94, 'h': 103, 'class': 3, 'class_name': 'You'}
# {'x': 928, 'y': 689, 'w': 67, 'h': 85, 'class': 1, 'class_name': 'Snake'}
# {'x': 1361, 'y': 672, 'w': 67, 'h': 63, 'class': 2, 'class_name': 'Spider'}
# {'x': 1263, 'y': 673, 'w': 73, 'h': 64, 'class': 3, 'class_name': 'You'}
#
# {'x': 1249, 'y': 478, 'w': 94, 'h': 103, 'class': 3, 'class_name': 'You'}
# {'x': 928, 'y': 689, 'w': 67, 'h': 85, 'class': 1, 'class_name': 'Snake'}
# {'x': 1361, 'y': 672, 'w': 67, 'h': 63, 'class': 2, 'class_name': 'Spider'}
# {'x': 1263, 'y': 673, 'w': 73, 'h': 64, 'class': 3, 'class_name': 'You'}
#
# {'x': 1249, 'y': 478, 'w': 95, 'h': 103, 'class': 3, 'class_name': 'You'}
# {'x': 931, 'y': 687, 'w': 65, 'h': 87, 'class': 1, 'class_name': 'Snake'}
# {'x': 1361, 'y': 672, 'w': 67, 'h': 63, 'class': 2, 'class_name': 'Spider'}
# {'x': 1263, 'y': 673, 'w': 73, 'h': 64, 'class': 3, 'class_name': 'You'}
#
# {'x': 1249, 'y': 478, 'w': 94, 'h': 103, 'class': 3, 'class_name': 'You'}
# {'x': 1361, 'y': 672, 'w': 67, 'h': 63, 'class': 2, 'class_name': 'Spider'}
# {'x': 926, 'y': 691, 'w': 67, 'h': 79, 'class': 1, 'class_name': 'Snake'}
# {'x': 1263, 'y': 673, 'w': 73, 'h': 64, 'class': 3, 'class_name': 'You'}
#
# {'x': 1249, 'y': 478, 'w': 94, 'h': 103, 'class': 3, 'class_name': 'You'}
# {'x': 1361, 'y': 672, 'w': 67, 'h': 63, 'class': 2, 'class_name': 'Spider'}
# {'x': 922, 'y': 689, 'w': 68, 'h': 80, 'class': 1, 'class_name': 'Snake'}
# {'x': 1263, 'y': 673, 'w': 74, 'h': 64, 'class': 3, 'class_name': 'You'}
#
# {'x': 1249, 'y': 478, 'w': 94, 'h': 103, 'class': 3, 'class_name': 'You'}
# {'x': 1361, 'y': 672, 'w': 67, 'h': 63, 'class': 2, 'class_name': 'Spider'}
# {'x': 922, 'y': 689, 'w': 68, 'h': 80, 'class': 1, 'class_name': 'Snake'}
# {'x': 1263, 'y': 673, 'w': 74, 'h': 64, 'class': 3, 'class_name': 'You'}
#
# {'x': 1249, 'y': 478, 'w': 94, 'h': 103, 'class': 3, 'class_name': 'You'}
# {'x': 1361, 'y': 672, 'w': 67, 'h': 63, 'class': 2, 'class_name': 'Spider'}
# {'x': 924, 'y': 691, 'w': 68, 'h': 78, 'class': 1, 'class_name': 'Snake'}
# {'x': 1264, 'y': 673, 'w': 73, 'h': 64, 'class': 3, 'class_name': 'You'}
#
# {'x': 1249, 'y': 478, 'w': 94, 'h': 103, 'class': 3, 'class_name': 'You'}
# {'x': 1361, 'y': 672, 'w': 67, 'h': 63, 'class': 2, 'class_name': 'Spider'}
# {'x': 924, 'y': 691, 'w': 68, 'h': 78, 'class': 1, 'class_name': 'Snake'}
# {'x': 1264, 'y': 673, 'w': 73, 'h': 64, 'class': 3, 'class_name': 'You'}
#
# {'x': 1249, 'y': 478, 'w': 94, 'h': 103, 'class': 3, 'class_name': 'You'}
# {'x': 929, 'y': 689, 'w': 62, 'h': 83, 'class': 1, 'class_name': 'Snake'}
# {'x': 1361, 'y': 672, 'w': 67, 'h': 63, 'class': 2, 'class_name': 'Spider'}
# {'x': 1263, 'y': 673, 'w': 73, 'h': 64, 'class': 3, 'class_name': 'You'}
#
# {'x': 1249, 'y': 478, 'w': 94, 'h': 103, 'class': 3, 'class_name': 'You'}
# {'x': 929, 'y': 689, 'w': 62, 'h': 83, 'class': 1, 'class_name': 'Snake'}
# {'x': 1361, 'y': 672, 'w': 67, 'h': 63, 'class': 2, 'class_name': 'Spider'}
# {'x': 1263, 'y': 673, 'w': 73, 'h': 64, 'class': 3, 'class_name': 'You'}
#
# {'x': 1249, 'y': 478, 'w': 94, 'h': 103, 'class': 3, 'class_name': 'You'}
# {'x': 929, 'y': 689, 'w': 62, 'h': 83, 'class': 1, 'class_name': 'Snake'}
# {'x': 1361, 'y': 672, 'w': 67, 'h': 63, 'class': 2, 'class_name': 'Spider'}
# {'x': 1263, 'y': 673, 'w': 73, 'h': 64, 'class': 3, 'class_name': 'You'}
#
# {'x': 1249, 'y': 478, 'w': 94, 'h': 103, 'class': 3, 'class_name': 'You'}
# {'x': 929, 'y': 689, 'w': 62, 'h': 83, 'class': 1, 'class_name': 'Snake'}
# {'x': 1361, 'y': 672, 'w': 67, 'h': 63, 'class': 2, 'class_name': 'Spider'}
# {'x': 1263, 'y': 673, 'w': 73, 'h': 64, 'class': 3, 'class_name': 'You'}
#
# {'x': 1249, 'y': 478, 'w': 94, 'h': 103, 'class': 3, 'class_name': 'You'}
# {'x': 929, 'y': 689, 'w': 62, 'h': 83, 'class': 1, 'class_name': 'Snake'}
# {'x': 1361, 'y': 672, 'w': 67, 'h': 63, 'class': 2, 'class_name': 'Spider'}
# {'x': 1263, 'y': 673, 'w': 73, 'h': 64, 'class': 3, 'class_name': 'You'}
#
# {'x': 1249, 'y': 478, 'w': 94, 'h': 103, 'class': 3, 'class_name': 'You'}
# {'x': 929, 'y': 689, 'w': 62, 'h': 83, 'class': 1, 'class_name': 'Snake'}
# {'x': 1361, 'y': 672, 'w': 67, 'h': 63, 'class': 2, 'class_name': 'Spider'}
# {'x': 1263, 'y': 673, 'w': 73, 'h': 64, 'class': 3, 'class_name': 'You'}
#
# {'x': 1249, 'y': 478, 'w': 94, 'h': 103, 'class': 3, 'class_name': 'You'}
# {'x': 929, 'y': 689, 'w': 62, 'h': 83, 'class': 1, 'class_name': 'Snake'}
# {'x': 1361, 'y': 672, 'w': 67, 'h': 63, 'class': 2, 'class_name': 'Spider'}
# {'x': 1263, 'y': 673, 'w': 73, 'h': 64, 'class': 3, 'class_name': 'You'}
#
# {'x': 1249, 'y': 478, 'w': 94, 'h': 103, 'class': 3, 'class_name': 'You'}
# {'x': 929, 'y': 689, 'w': 62, 'h': 83, 'class': 1, 'class_name': 'Snake'}
# {'x': 1361, 'y': 672, 'w': 67, 'h': 63, 'class': 2, 'class_name': 'Spider'}
# {'x': 1263, 'y': 673, 'w': 73, 'h': 64, 'class': 3, 'class_name': 'You'}
#
# {'x': 1249, 'y': 478, 'w': 94, 'h': 103, 'class': 3, 'class_name': 'You'}
# {'x': 929, 'y': 689, 'w': 62, 'h': 83, 'class': 1, 'class_name': 'Snake'}
# {'x': 1361, 'y': 672, 'w': 67, 'h': 63, 'class': 2, 'class_name': 'Spider'}
# {'x': 1263, 'y': 673, 'w': 73, 'h': 64, 'class': 3, 'class_name': 'You'}
#
# {'x': 1249, 'y': 478, 'w': 94, 'h': 103, 'class': 3, 'class_name': 'You'}
# {'x': 929, 'y': 689, 'w': 62, 'h': 83, 'class': 1, 'class_name': 'Snake'}
# {'x': 1361, 'y': 672, 'w': 67, 'h': 63, 'class': 2, 'class_name': 'Spider'}
# {'x': 1263, 'y': 673, 'w': 73, 'h': 64, 'class': 3, 'class_name': 'You'}
#
# {'x': 1249, 'y': 478, 'w': 94, 'h': 103, 'class': 3, 'class_name': 'You'}
# {'x': 929, 'y': 689, 'w': 62, 'h': 83, 'class': 1, 'class_name': 'Snake'}
# {'x': 1361, 'y': 672, 'w': 67, 'h': 63, 'class': 2, 'class_name': 'Spider'}
# {'x': 1263, 'y': 673, 'w': 73, 'h': 64, 'class': 3, 'class_name': 'You'}
#
# {'x': 1249, 'y': 478, 'w': 94, 'h': 103, 'class': 3, 'class_name': 'You'}
# {'x': 929, 'y': 689, 'w': 62, 'h': 83, 'class': 1, 'class_name': 'Snake'}
# {'x': 1361, 'y': 672, 'w': 67, 'h': 63, 'class': 2, 'class_name': 'Spider'}
# {'x': 1263, 'y': 673, 'w': 73, 'h': 64, 'class': 3, 'class_name': 'You'}
#
# {'x': 1249, 'y': 478, 'w': 94, 'h': 103, 'class': 3, 'class_name': 'You'}
# {'x': 929, 'y': 689, 'w': 62, 'h': 83, 'class': 1, 'class_name': 'Snake'}
# {'x': 1361, 'y': 672, 'w': 67, 'h': 63, 'class': 2, 'class_name': 'Spider'}
# {'x': 1263, 'y': 673, 'w': 73, 'h': 64, 'class': 3, 'class_name': 'You'}
#
# {'x': 1249, 'y': 478, 'w': 94, 'h': 103, 'class': 3, 'class_name': 'You'}
# {'x': 929, 'y': 689, 'w': 62, 'h': 83, 'class': 1, 'class_name': 'Snake'}
# {'x': 1361, 'y': 672, 'w': 67, 'h': 63, 'class': 2, 'class_name': 'Spider'}
# {'x': 1263, 'y': 673, 'w': 73, 'h': 64, 'class': 3, 'class_name': 'You'}
#
# {'x': 1249, 'y': 478, 'w': 94, 'h': 103, 'class': 3, 'class_name': 'You'}
# {'x': 929, 'y': 689, 'w': 62, 'h': 83, 'class': 1, 'class_name': 'Snake'}
# {'x': 1361, 'y': 672, 'w': 67, 'h': 63, 'class': 2, 'class_name': 'Spider'}
# {'x': 1263, 'y': 673, 'w': 73, 'h': 64, 'class': 3, 'class_name': 'You'}
#
# {'x': 1249, 'y': 478, 'w': 94, 'h': 103, 'class': 3, 'class_name': 'You'}
# {'x': 929, 'y': 689, 'w': 62, 'h': 83, 'class': 1, 'class_name': 'Snake'}
# {'x': 1361, 'y': 672, 'w': 67, 'h': 63, 'class': 2, 'class_name': 'Spider'}
# {'x': 1263, 'y': 673, 'w': 73, 'h': 64, 'class': 3, 'class_name': 'You'}
#
# {'x': 1249, 'y': 478, 'w': 94, 'h': 103, 'class': 3, 'class_name': 'You'}
# {'x': 929, 'y': 689, 'w': 62, 'h': 83, 'class': 1, 'class_name': 'Snake'}
# {'x': 1361, 'y': 672, 'w': 67, 'h': 63, 'class': 2, 'class_name': 'Spider'}
# {'x': 1263, 'y': 673, 'w': 73, 'h': 64, 'class': 3, 'class_name': 'You'}
#
# {'x': 1249, 'y': 478, 'w': 94, 'h': 103, 'class': 3, 'class_name': 'You'}
# {'x': 929, 'y': 689, 'w': 62, 'h': 83, 'class': 1, 'class_name': 'Snake'}
# {'x': 1361, 'y': 672, 'w': 67, 'h': 63, 'class': 2, 'class_name': 'Spider'}
# {'x': 1263, 'y': 673, 'w': 73, 'h': 64, 'class': 3, 'class_name': 'You'}
#
# {'x': 1249, 'y': 478, 'w': 94, 'h': 103, 'class': 3, 'class_name': 'You'}
# {'x': 929, 'y': 689, 'w': 62, 'h': 83, 'class': 1, 'class_name': 'Snake'}
# {'x': 1361, 'y': 672, 'w': 67, 'h': 63, 'class': 2, 'class_name': 'Spider'}
# {'x': 1263, 'y': 673, 'w': 73, 'h': 64, 'class': 3, 'class_name': 'You'}
#
# {'x': 1249, 'y': 478, 'w': 94, 'h': 103, 'class': 3, 'class_name': 'You'}
# {'x': 929, 'y': 689, 'w': 62, 'h': 83, 'class': 1, 'class_name': 'Snake'}
# {'x': 1361, 'y': 672, 'w': 67, 'h': 63, 'class': 2, 'class_name': 'Spider'}
# {'x': 1263, 'y': 673, 'w': 73, 'h': 64, 'class': 3, 'class_name': 'You'}
#
# {'x': 1249, 'y': 478, 'w': 94, 'h': 103, 'class': 3, 'class_name': 'You'}
# {'x': 929, 'y': 689, 'w': 62, 'h': 83, 'class': 1, 'class_name': 'Snake'}
# {'x': 1361, 'y': 672, 'w': 67, 'h': 63, 'class': 2, 'class_name': 'Spider'}
# {'x': 1263, 'y': 673, 'w': 73, 'h': 64, 'class': 3, 'class_name': 'You'}
#
# {'x': 1249, 'y': 478, 'w': 94, 'h': 103, 'class': 3, 'class_name': 'You'}
# {'x': 929, 'y': 689, 'w': 62, 'h': 83, 'class': 1, 'class_name': 'Snake'}
# {'x': 1361, 'y': 672, 'w': 67, 'h': 63, 'class': 2, 'class_name': 'Spider'}
# {'x': 1263, 'y': 673, 'w': 73, 'h': 64, 'class': 3, 'class_name': 'You'}
#
# {'x': 1249, 'y': 478, 'w': 94, 'h': 103, 'class': 3, 'class_name': 'You'}
# {'x': 929, 'y': 689, 'w': 62, 'h': 83, 'class': 1, 'class_name': 'Snake'}
# {'x': 1361, 'y': 672, 'w': 67, 'h': 63, 'class': 2, 'class_name': 'Spider'}
# {'x': 1263, 'y': 673, 'w': 73, 'h': 64, 'class': 3, 'class_name': 'You'}
#
# {'x': 1249, 'y': 478, 'w': 94, 'h': 103, 'class': 3, 'class_name': 'You'}
# {'x': 929, 'y': 689, 'w': 62, 'h': 83, 'class': 1, 'class_name': 'Snake'}
# {'x': 1361, 'y': 672, 'w': 67, 'h': 63, 'class': 2, 'class_name': 'Spider'}
# {'x': 1263, 'y': 673, 'w': 73, 'h': 64, 'class': 3, 'class_name': 'You'}
#
# {'x': 1249, 'y': 478, 'w': 94, 'h': 103, 'class': 3, 'class_name': 'You'}
# {'x': 929, 'y': 689, 'w': 62, 'h': 83, 'class': 1, 'class_name': 'Snake'}
# {'x': 1361, 'y': 672, 'w': 67, 'h': 63, 'class': 2, 'class_name': 'Spider'}
# {'x': 1263, 'y': 673, 'w': 73, 'h': 64, 'class': 3, 'class_name': 'You'}
#
# {'x': 1249, 'y': 478, 'w': 94, 'h': 103, 'class': 3, 'class_name': 'You'}
# {'x': 929, 'y': 689, 'w': 62, 'h': 83, 'class': 1, 'class_name': 'Snake'}
# {'x': 1361, 'y': 672, 'w': 67, 'h': 63, 'class': 2, 'class_name': 'Spider'}
# {'x': 1263, 'y': 673, 'w': 73, 'h': 64, 'class': 3, 'class_name': 'You'}
#
# {'x': 1249, 'y': 478, 'w': 94, 'h': 103, 'class': 3, 'class_name': 'You'}
# {'x': 929, 'y': 689, 'w': 62, 'h': 83, 'class': 1, 'class_name': 'Snake'}
# {'x': 1361, 'y': 672, 'w': 67, 'h': 63, 'class': 2, 'class_name': 'Spider'}
# {'x': 1263, 'y': 673, 'w': 73, 'h': 64, 'class': 3, 'class_name': 'You'}
#
# {'x': 1249, 'y': 478, 'w': 94, 'h': 103, 'class': 3, 'class_name': 'You'}
# {'x': 929, 'y': 689, 'w': 62, 'h': 83, 'class': 1, 'class_name': 'Snake'}
# {'x': 1361, 'y': 672, 'w': 67, 'h': 63, 'class': 2, 'class_name': 'Spider'}
# {'x': 1263, 'y': 673, 'w': 73, 'h': 64, 'class': 3, 'class_name': 'You'}
#
# {'x': 1249, 'y': 478, 'w': 94, 'h': 103, 'class': 3, 'class_name': 'You'}
# {'x': 929, 'y': 689, 'w': 62, 'h': 83, 'class': 1, 'class_name': 'Snake'}
# {'x': 1361, 'y': 672, 'w': 67, 'h': 63, 'class': 2, 'class_name': 'Spider'}
# {'x': 1263, 'y': 673, 'w': 73, 'h': 64, 'class': 3, 'class_name': 'You'}
#
# {'x': 1249, 'y': 478, 'w': 94, 'h': 103, 'class': 3, 'class_name': 'You'}
# {'x': 929, 'y': 689, 'w': 62, 'h': 83, 'class': 1, 'class_name': 'Snake'}
# {'x': 1361, 'y': 672, 'w': 67, 'h': 63, 'class': 2, 'class_name': 'Spider'}
# {'x': 1263, 'y': 673, 'w': 73, 'h': 64, 'class': 3, 'class_name': 'You'}
#
# {'x': 1249, 'y': 478, 'w': 94, 'h': 103, 'class': 3, 'class_name': 'You'}
# {'x': 929, 'y': 689, 'w': 62, 'h': 83, 'class': 1, 'class_name': 'Snake'}
# {'x': 1361, 'y': 672, 'w': 67, 'h': 63, 'class': 2, 'class_name': 'Spider'}
# {'x': 1263, 'y': 673, 'w': 73, 'h': 64, 'class': 3, 'class_name': 'You'}
#
# {'x': 1249, 'y': 478, 'w': 94, 'h': 103, 'class': 3, 'class_name': 'You'}
# {'x': 929, 'y': 689, 'w': 62, 'h': 83, 'class': 1, 'class_name': 'Snake'}
# {'x': 1361, 'y': 672, 'w': 67, 'h': 63, 'class': 2, 'class_name': 'Spider'}
# {'x': 1263, 'y': 673, 'w': 73, 'h': 64, 'class': 3, 'class_name': 'You'}
#
# {'x': 1249, 'y': 478, 'w': 94, 'h': 103, 'class': 3, 'class_name': 'You'}
# {'x': 929, 'y': 689, 'w': 62, 'h': 83, 'class': 1, 'class_name': 'Snake'}
# {'x': 1361, 'y': 672, 'w': 67, 'h': 63, 'class': 2, 'class_name': 'Spider'}
# {'x': 1263, 'y': 673, 'w': 73, 'h': 64, 'class': 3, 'class_name': 'You'}
#
# {'x': 1249, 'y': 478, 'w': 94, 'h': 103, 'class': 3, 'class_name': 'You'}
# {'x': 929, 'y': 689, 'w': 62, 'h': 83, 'class': 1, 'class_name': 'Snake'}
# {'x': 1361, 'y': 672, 'w': 67, 'h': 63, 'class': 2, 'class_name': 'Spider'}
# {'x': 1263, 'y': 673, 'w': 73, 'h': 64, 'class': 3, 'class_name': 'You'}
#
# {'x': 1249, 'y': 478, 'w': 94, 'h': 103, 'class': 3, 'class_name': 'You'}
# {'x': 929, 'y': 689, 'w': 62, 'h': 83, 'class': 1, 'class_name': 'Snake'}
# {'x': 1361, 'y': 672, 'w': 67, 'h': 63, 'class': 2, 'class_name': 'Spider'}
# {'x': 1263, 'y': 673, 'w': 73, 'h': 64, 'class': 3, 'class_name': 'You'}
#
# {'x': 1249, 'y': 478, 'w': 94, 'h': 103, 'class': 3, 'class_name': 'You'}
# {'x': 929, 'y': 689, 'w': 62, 'h': 83, 'class': 1, 'class_name': 'Snake'}
# {'x': 1361, 'y': 672, 'w': 67, 'h': 63, 'class': 2, 'class_name': 'Spider'}
# {'x': 1263, 'y': 673, 'w': 73, 'h': 64, 'class': 3, 'class_name': 'You'}
#
# {'x': 1249, 'y': 478, 'w': 94, 'h': 103, 'class': 3, 'class_name': 'You'}
# {'x': 929, 'y': 689, 'w': 62, 'h': 83, 'class': 1, 'class_name': 'Snake'}
# {'x': 1361, 'y': 672, 'w': 67, 'h': 63, 'class': 2, 'class_name': 'Spider'}
# {'x': 1263, 'y': 673, 'w': 73, 'h': 64, 'class': 3, 'class_name': 'You'}
#
# {'x': 1249, 'y': 478, 'w': 94, 'h': 103, 'class': 3, 'class_name': 'You'}
# {'x': 929, 'y': 689, 'w': 62, 'h': 83, 'class': 1, 'class_name': 'Snake'}
# {'x': 1361, 'y': 672, 'w': 67, 'h': 63, 'class': 2, 'class_name': 'Spider'}
# {'x': 1263, 'y': 673, 'w': 73, 'h': 64, 'class': 3, 'class_name': 'You'}
#
# {'x': 1249, 'y': 478, 'w': 94, 'h': 103, 'class': 3, 'class_name': 'You'}
# {'x': 929, 'y': 689, 'w': 62, 'h': 83, 'class': 1, 'class_name': 'Snake'}
# {'x': 1361, 'y': 672, 'w': 67, 'h': 63, 'class': 2, 'class_name': 'Spider'}
# {'x': 1263, 'y': 673, 'w': 73, 'h': 64, 'class': 3, 'class_name': 'You'}
#
# {'x': 1249, 'y': 478, 'w': 94, 'h': 103, 'class': 3, 'class_name': 'You'}
# {'x': 929, 'y': 689, 'w': 62, 'h': 83, 'class': 1, 'class_name': 'Snake'}
# {'x': 1361, 'y': 672, 'w': 67, 'h': 63, 'class': 2, 'class_name': 'Spider'}
# {'x': 1263, 'y': 673, 'w': 73, 'h': 64, 'class': 3, 'class_name': 'You'}
#
# {'x': 1249, 'y': 478, 'w': 94, 'h': 103, 'class': 3, 'class_name': 'You'}
# {'x': 929, 'y': 689, 'w': 62, 'h': 83, 'class': 1, 'class_name': 'Snake'}
# {'x': 1361, 'y': 672, 'w': 67, 'h': 63, 'class': 2, 'class_name': 'Spider'}
# {'x': 1263, 'y': 673, 'w': 73, 'h': 64, 'class': 3, 'class_name': 'You'}
#
# {'x': 1249, 'y': 478, 'w': 94, 'h': 103, 'class': 3, 'class_name': 'You'}
# {'x': 929, 'y': 689, 'w': 62, 'h': 83, 'class': 1, 'class_name': 'Snake'}
# {'x': 1361, 'y': 672, 'w': 67, 'h': 63, 'class': 2, 'class_name': 'Spider'}
# {'x': 1263, 'y': 673, 'w': 73, 'h': 64, 'class': 3, 'class_name': 'You'}
#
# {'x': 1249, 'y': 478, 'w': 94, 'h': 103, 'class': 3, 'class_name': 'You'}
# {'x': 929, 'y': 689, 'w': 62, 'h': 83, 'class': 1, 'class_name': 'Snake'}
# {'x': 1361, 'y': 672, 'w': 67, 'h': 63, 'class': 2, 'class_name': 'Spider'}
# {'x': 1263, 'y': 673, 'w': 73, 'h': 64, 'class': 3, 'class_name': 'You'}
#
# {'x': 1249, 'y': 478, 'w': 94, 'h': 103, 'class': 3, 'class_name': 'You'}
# {'x': 929, 'y': 689, 'w': 62, 'h': 83, 'class': 1, 'class_name': 'Snake'}
# {'x': 1361, 'y': 672, 'w': 67, 'h': 63, 'class': 2, 'class_name': 'Spider'}
# {'x': 1263, 'y': 673, 'w': 73, 'h': 64, 'class': 3, 'class_name': 'You'}
#
# {'x': 1249, 'y': 478, 'w': 94, 'h': 103, 'class': 3, 'class_name': 'You'}
# {'x': 929, 'y': 689, 'w': 62, 'h': 83, 'class': 1, 'class_name': 'Snake'}
# {'x': 1361, 'y': 672, 'w': 67, 'h': 63, 'class': 2, 'class_name': 'Spider'}
# {'x': 1263, 'y': 673, 'w': 73, 'h': 64, 'class': 3, 'class_name': 'You'}
#
# {'x': 1249, 'y': 478, 'w': 94, 'h': 103, 'class': 3, 'class_name': 'You'}
# {'x': 929, 'y': 689, 'w': 62, 'h': 83, 'class': 1, 'class_name': 'Snake'}
# {'x': 1361, 'y': 672, 'w': 67, 'h': 63, 'class': 2, 'class_name': 'Spider'}
# {'x': 1263, 'y': 673, 'w': 73, 'h': 64, 'class': 3, 'class_name': 'You'}
#
# {'x': 1249, 'y': 478, 'w': 94, 'h': 103, 'class': 3, 'class_name': 'You'}
# {'x': 929, 'y': 689, 'w': 62, 'h': 83, 'class': 1, 'class_name': 'Snake'}
# {'x': 1361, 'y': 672, 'w': 67, 'h': 63, 'class': 2, 'class_name': 'Spider'}
# {'x': 1263, 'y': 673, 'w': 73, 'h': 64, 'class': 3, 'class_name': 'You'}
#
# {'x': 1249, 'y': 478, 'w': 94, 'h': 103, 'class': 3, 'class_name': 'You'}
# {'x': 929, 'y': 689, 'w': 62, 'h': 83, 'class': 1, 'class_name': 'Snake'}
# {'x': 1361, 'y': 672, 'w': 67, 'h': 63, 'class': 2, 'class_name': 'Spider'}
# {'x': 1263, 'y': 673, 'w': 73, 'h': 64, 'class': 3, 'class_name': 'You'}
#
# {'x': 1249, 'y': 478, 'w': 94, 'h': 103, 'class': 3, 'class_name': 'You'}
# {'x': 929, 'y': 689, 'w': 62, 'h': 83, 'class': 1, 'class_name': 'Snake'}
# {'x': 1361, 'y': 672, 'w': 67, 'h': 63, 'class': 2, 'class_name': 'Spider'}
# {'x': 1263, 'y': 673, 'w': 73, 'h': 64, 'class': 3, 'class_name': 'You'}
#
# {'x': 1249, 'y': 478, 'w': 94, 'h': 103, 'class': 3, 'class_name': 'You'}
# {'x': 929, 'y': 689, 'w': 62, 'h': 83, 'class': 1, 'class_name': 'Snake'}
# {'x': 1361, 'y': 672, 'w': 67, 'h': 63, 'class': 2, 'class_name': 'Spider'}
# {'x': 1263, 'y': 673, 'w': 73, 'h': 64, 'class': 3, 'class_name': 'You'}
#
# {'x': 1249, 'y': 478, 'w': 94, 'h': 103, 'class': 3, 'class_name': 'You'}
# {'x': 929, 'y': 689, 'w': 62, 'h': 83, 'class': 1, 'class_name': 'Snake'}
# {'x': 1361, 'y': 672, 'w': 67, 'h': 63, 'class': 2, 'class_name': 'Spider'}
# {'x': 1263, 'y': 673, 'w': 73, 'h': 64, 'class': 3, 'class_name': 'You'}
#
# {'x': 1249, 'y': 478, 'w': 94, 'h': 103, 'class': 3, 'class_name': 'You'}
# {'x': 929, 'y': 689, 'w': 62, 'h': 83, 'class': 1, 'class_name': 'Snake'}
# {'x': 1361, 'y': 672, 'w': 67, 'h': 63, 'class': 2, 'class_name': 'Spider'}
# {'x': 1263, 'y': 673, 'w': 73, 'h': 64, 'class': 3, 'class_name': 'You'}
#
# {'x': 1249, 'y': 478, 'w': 94, 'h': 103, 'class': 3, 'class_name': 'You'}
# {'x': 929, 'y': 689, 'w': 62, 'h': 83, 'class': 1, 'class_name': 'Snake'}
# {'x': 1361, 'y': 672, 'w': 67, 'h': 63, 'class': 2, 'class_name': 'Spider'}
# {'x': 1263, 'y': 673, 'w': 73, 'h': 64, 'class': 3, 'class_name': 'You'}
#
# {'x': 1249, 'y': 478, 'w': 94, 'h': 103, 'class': 3, 'class_name': 'You'}
# {'x': 929, 'y': 689, 'w': 62, 'h': 83, 'class': 1, 'class_name': 'Snake'}
# {'x': 1361, 'y': 672, 'w': 67, 'h': 63, 'class': 2, 'class_name': 'Spider'}
# {'x': 1263, 'y': 673, 'w': 73, 'h': 64, 'class': 3, 'class_name': 'You'}
#
# {'x': 1249, 'y': 478, 'w': 94, 'h': 103, 'class': 3, 'class_name': 'You'}
# {'x': 929, 'y': 689, 'w': 62, 'h': 83, 'class': 1, 'class_name': 'Snake'}
# {'x': 1361, 'y': 672, 'w': 67, 'h': 63, 'class': 2, 'class_name': 'Spider'}
# {'x': 1263, 'y': 673, 'w': 73, 'h': 64, 'class': 3, 'class_name': 'You'}
#
# {'x': 1249, 'y': 478, 'w': 94, 'h': 103, 'class': 3, 'class_name': 'You'}
# {'x': 929, 'y': 689, 'w': 62, 'h': 83, 'class': 1, 'class_name': 'Snake'}
# {'x': 1361, 'y': 672, 'w': 67, 'h': 63, 'class': 2, 'class_name': 'Spider'}
# {'x': 1263, 'y': 673, 'w': 73, 'h': 64, 'class': 3, 'class_name': 'You'}
#
# {'x': 1249, 'y': 478, 'w': 94, 'h': 103, 'class': 3, 'class_name': 'You'}
# {'x': 929, 'y': 689, 'w': 62, 'h': 83, 'class': 1, 'class_name': 'Snake'}
# {'x': 1361, 'y': 672, 'w': 67, 'h': 63, 'class': 2, 'class_name': 'Spider'}
# {'x': 1263, 'y': 673, 'w': 73, 'h': 64, 'class': 3, 'class_name': 'You'}
#
# {'x': 1249, 'y': 478, 'w': 94, 'h': 103, 'class': 3, 'class_name': 'You'}
# {'x': 929, 'y': 689, 'w': 62, 'h': 83, 'class': 1, 'class_name': 'Snake'}
# {'x': 1361, 'y': 672, 'w': 67, 'h': 63, 'class': 2, 'class_name': 'Spider'}
# {'x': 1263, 'y': 673, 'w': 73, 'h': 64, 'class': 3, 'class_name': 'You'}
#
# {'x': 1249, 'y': 478, 'w': 94, 'h': 103, 'class': 3, 'class_name': 'You'}
# {'x': 929, 'y': 689, 'w': 62, 'h': 83, 'class': 1, 'class_name': 'Snake'}
# {'x': 1361, 'y': 672, 'w': 67, 'h': 63, 'class': 2, 'class_name': 'Spider'}
# {'x': 1263, 'y': 673, 'w': 73, 'h': 64, 'class': 3, 'class_name': 'You'}
#
# {'x': 1249, 'y': 478, 'w': 94, 'h': 103, 'class': 3, 'class_name': 'You'}
# {'x': 929, 'y': 689, 'w': 62, 'h': 83, 'class': 1, 'class_name': 'Snake'}
# {'x': 1361, 'y': 672, 'w': 67, 'h': 63, 'class': 2, 'class_name': 'Spider'}
# {'x': 1263, 'y': 673, 'w': 73, 'h': 64, 'class': 3, 'class_name': 'You'}
#
# {'x': 1249, 'y': 478, 'w': 94, 'h': 103, 'class': 3, 'class_name': 'You'}
# {'x': 929, 'y': 689, 'w': 62, 'h': 83, 'class': 1, 'class_name': 'Snake'}
# {'x': 1361, 'y': 672, 'w': 67, 'h': 63, 'class': 2, 'class_name': 'Spider'}
# {'x': 1263, 'y': 673, 'w': 73, 'h': 64, 'class': 3, 'class_name': 'You'}
#
# {'x': 1249, 'y': 478, 'w': 94, 'h': 103, 'class': 3, 'class_name': 'You'}
# {'x': 929, 'y': 689, 'w': 62, 'h': 83, 'class': 1, 'class_name': 'Snake'}
# {'x': 1361, 'y': 672, 'w': 67, 'h': 63, 'class': 2, 'class_name': 'Spider'}
# {'x': 1263, 'y': 673, 'w': 73, 'h': 64, 'class': 3, 'class_name': 'You'}
#
# {'x': 1249, 'y': 478, 'w': 94, 'h': 103, 'class': 3, 'class_name': 'You'}
# {'x': 929, 'y': 689, 'w': 62, 'h': 83, 'class': 1, 'class_name': 'Snake'}
# {'x': 1361, 'y': 672, 'w': 67, 'h': 63, 'class': 2, 'class_name': 'Spider'}
# ...
#
# {'x': 870, 'y': 427, 'w': 91, 'h': 103, 'class': 3, 'class_name': 'You'}
#
# {'x': 864, 'y': 438, 'w': 76, 'h': 110, 'class': 3, 'class_name': 'You'}
#
# {'x': 887, 'y': 443, 'w': 79, 'h': 106, 'class': 3, 'class_name': 'You'}
# {'x': 1260, 'y': 821, 'w': 106, 'h': 32, 'class': 2, 'class_name': 'Spider'}
#
# {'x': 903, 'y': 446, 'w': 76, 'h': 110, 'class': 3, 'class_name': 'You'}
#
# {'x': 905, 'y': 444, 'w': 87, 'h': 104, 'class': 3, 'class_name': 'You'}
#
# {'x': 911, 'y': 428, 'w': 85, 'h': 103, 'class': 3, 'class_name': 'You'}
#
# {'x': 912, 'y': 409, 'w': 86, 'h': 106, 'class': 3, 'class_name': 'You'}
#
# {'x': 910, 'y': 390, 'w': 85, 'h': 102, 'class': 3, 'class_name': 'You'}
#
# {'x': 908, 'y': 369, 'w': 89, 'h': 108, 'class': 3, 'class_name': 'You'}
#
# {'x': 909, 'y': 352, 'w': 87, 'h': 108, 'class': 3, 'class_name': 'You'}
#
# {'x': 907, 'y': 292, 'w': 72, 'h': 113, 'class': 3, 'class_name': 'You'}
#
# {'x': 914, 'y': 287, 'w': 73, 'h': 118, 'class': 3, 'class_name': 'You'}
#
# {'x': 917, 'y': 316, 'w': 72, 'h': 104, 'class': 3, 'class_name': 'You'}
#
# {'x': 903, 'y': 360, 'w': 83, 'h': 97, 'class': 3, 'class_name': 'You'}
#
# {'x': 897, 'y': 364, 'w': 73, 'h': 89, 'class': 3, 'class_name': 'You'}
#
# {'x': 906, 'y': 368, 'w': 57, 'h': 81, 'class': 3, 'class_name': 'You'}
#
# {'x': 884, 'y': 370, 'w': 49, 'h': 75, 'class': 3, 'class_name': 'You'}
#
# {'x': 886, 'y': 363, 'w': 62, 'h': 89, 'class': 3, 'class_name': 'You'}
#
# {'x': 892, 'y': 361, 'w': 70, 'h': 94, 'class': 3, 'class_name': 'You'}
#
# {'x': 896, 'y': 365, 'w': 75, 'h': 90, 'class': 3, 'class_name': 'You'}
#
# {'x': 902, 'y': 360, 'w': 77, 'h': 96, 'class': 3, 'class_name': 'You'}
#
# {'x': 904, 'y': 363, 'w': 78, 'h': 93, 'class': 3, 'class_name': 'You'}
#
# {'x': 902, 'y': 363, 'w': 81, 'h': 94, 'class': 3, 'class_name': 'You'}
#
# {'x': 904, 'y': 363, 'w': 80, 'h': 94, 'class': 3, 'class_name': 'You'}
#
# {'x': 901, 'y': 362, 'w': 87, 'h': 99, 'class': 3, 'class_name': 'You'}
#
# {'x': 901, 'y': 360, 'w': 85, 'h': 98, 'class': 3, 'class_name': 'You'}
#
# {'x': 900, 'y': 361, 'w': 89, 'h': 98, 'class': 3, 'class_name': 'You'}
#
# {'x': 903, 'y': 362, 'w': 85, 'h': 101, 'class': 3, 'class_name': 'You'}
#
# {'x': 903, 'y': 362, 'w': 88, 'h': 101, 'class': 3, 'class_name': 'You'}
#
# {'x': 902, 'y': 364, 'w': 88, 'h': 97, 'class': 3, 'class_name': 'You'}
#
# {'x': 900, 'y': 363, 'w': 94, 'h': 95, 'class': 3, 'class_name': 'You'}
#
# {'x': 903, 'y': 362, 'w': 88, 'h': 96, 'class': 3, 'class_name': 'You'}
#
# {'x': 905, 'y': 363, 'w': 92, 'h': 99, 'class': 3, 'class_name': 'You'}
#
# {'x': 907, 'y': 363, 'w': 95, 'h': 96, 'class': 3, 'class_name': 'You'}
#
# {'x': 898, 'y': 364, 'w': 94, 'h': 101, 'class': 3, 'class_name': 'You'}
#
# {'x': 884, 'y': 359, 'w': 91, 'h': 105, 'class': 3, 'class_name': 'You'}
#
# {'x': 870, 'y': 358, 'w': 89, 'h': 115, 'class': 3, 'class_name': 'You'}
#
# {'x': 871, 'y': 383, 'w': 88, 'h': 121, 'class': 3, 'class_name': 'You'}
#
# {'x': 870, 'y': 437, 'w': 93, 'h': 117, 'class': 3, 'class_name': 'You'}
#
# {'x': 878, 'y': 501, 'w': 96, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 909, 'y': 552, 'w': 92, 'h': 115, 'class': 3, 'class_name': 'You'}
#
# {'x': 934, 'y': 593, 'w': 87, 'h': 114, 'class': 3, 'class_name': 'You'}
#
# {'x': 940, 'y': 553, 'w': 85, 'h': 108, 'class': 3, 'class_name': 'You'}
#
# {'x': 933, 'y': 508, 'w': 80, 'h': 107, 'class': 3, 'class_name': 'You'}
#
# {'x': 904, 'y': 488, 'w': 88, 'h': 106, 'class': 3, 'class_name': 'You'}
#
# {'x': 892, 'y': 481, 'w': 80, 'h': 100, 'class': 3, 'class_name': 'You'}
#
# {'x': 885, 'y': 460, 'w': 80, 'h': 108, 'class': 3, 'class_name': 'You'}
#
# {'x': 871, 'y': 413, 'w': 95, 'h': 116, 'class': 3, 'class_name': 'You'}
#
# {'x': 867, 'y': 417, 'w': 93, 'h': 118, 'class': 3, 'class_name': 'You'}
#
# {'x': 869, 'y': 438, 'w': 89, 'h': 118, 'class': 3, 'class_name': 'You'}
#
# {'x': 873, 'y': 456, 'w': 87, 'h': 116, 'class': 3, 'class_name': 'You'}
#
# {'x': 870, 'y': 490, 'w': 89, 'h': 116, 'class': 3, 'class_name': 'You'}
#
# {'x': 870, 'y': 520, 'w': 96, 'h': 113, 'class': 3, 'class_name': 'You'}
#
# {'x': 876, 'y': 525, 'w': 84, 'h': 95, 'class': 3, 'class_name': 'You'}
#
# {'x': 855, 'y': 496, 'w': 77, 'h': 95, 'class': 3, 'class_name': 'You'}
#
# {'x': 841, 'y': 457, 'w': 85, 'h': 108, 'class': 3, 'class_name': 'You'}
#
# {'x': 836, 'y': 427, 'w': 93, 'h': 104, 'class': 3, 'class_name': 'You'}
#
# {'x': 816, 'y': 439, 'w': 86, 'h': 90, 'class': 3, 'class_name': 'You'}
#
# {'x': 804, 'y': 457, 'w': 75, 'h': 97, 'class': 3, 'class_name': 'You'}
#
# {'x': 769, 'y': 473, 'w': 83, 'h': 96, 'class': 3, 'class_name': 'You'}
#
# {'x': 743, 'y': 477, 'w': 85, 'h': 93, 'class': 3, 'class_name': 'You'}
#
# {'x': 725, 'y': 479, 'w': 86, 'h': 98, 'class': 3, 'class_name': 'You'}
#
# {'x': 726, 'y': 479, 'w': 86, 'h': 98, 'class': 3, 'class_name': 'You'}
#
# {'x': 726, 'y': 479, 'w': 87, 'h': 98, 'class': 3, 'class_name': 'You'}
#
# {'x': 725, 'y': 479, 'w': 87, 'h': 99, 'class': 3, 'class_name': 'You'}
#
# {'x': 725, 'y': 478, 'w': 86, 'h': 100, 'class': 3, 'class_name': 'You'}
#
# {'x': 725, 'y': 478, 'w': 86, 'h': 100, 'class': 3, 'class_name': 'You'}
#
# {'x': 724, 'y': 479, 'w': 87, 'h': 99, 'class': 3, 'class_name': 'You'}
#
# {'x': 724, 'y': 478, 'w': 86, 'h': 98, 'class': 3, 'class_name': 'You'}
#
# {'x': 724, 'y': 479, 'w': 86, 'h': 99, 'class': 3, 'class_name': 'You'}
#
# {'x': 724, 'y': 479, 'w': 86, 'h': 99, 'class': 3, 'class_name': 'You'}
#
# {'x': 728, 'y': 475, 'w': 96, 'h': 95, 'class': 3, 'class_name': 'You'}
#
# {'x': 731, 'y': 478, 'w': 84, 'h': 91, 'class': 3, 'class_name': 'You'}
#
# {'x': 722, 'y': 478, 'w': 87, 'h': 100, 'class': 3, 'class_name': 'You'}
#
# {'x': 725, 'y': 479, 'w': 87, 'h': 98, 'class': 3, 'class_name': 'You'}
#
# {'x': 724, 'y': 479, 'w': 90, 'h': 98, 'class': 3, 'class_name': 'You'}
#
# {'x': 725, 'y': 479, 'w': 86, 'h': 99, 'class': 3, 'class_name': 'You'}
#
# {'x': 725, 'y': 479, 'w': 86, 'h': 99, 'class': 3, 'class_name': 'You'}
#
# {'x': 725, 'y': 479, 'w': 86, 'h': 99, 'class': 3, 'class_name': 'You'}
#
# {'x': 725, 'y': 479, 'w': 86, 'h': 99, 'class': 3, 'class_name': 'You'}
#
# {'x': 725, 'y': 479, 'w': 86, 'h': 99, 'class': 3, 'class_name': 'You'}
#
# {'x': 725, 'y': 479, 'w': 86, 'h': 99, 'class': 3, 'class_name': 'You'}
#
# {'x': 725, 'y': 479, 'w': 86, 'h': 99, 'class': 3, 'class_name': 'You'}
#
# {'x': 725, 'y': 479, 'w': 86, 'h': 99, 'class': 3, 'class_name': 'You'}
#
# {'x': 725, 'y': 479, 'w': 86, 'h': 99, 'class': 3, 'class_name': 'You'}
#
# {'x': 725, 'y': 479, 'w': 86, 'h': 99, 'class': 3, 'class_name': 'You'}
#
# {'x': 725, 'y': 479, 'w': 86, 'h': 99, 'class': 3, 'class_name': 'You'}
#
# {'x': 725, 'y': 479, 'w': 86, 'h': 99, 'class': 3, 'class_name': 'You'}
#
# {'x': 725, 'y': 479, 'w': 86, 'h': 99, 'class': 3, 'class_name': 'You'}
#
# {'x': 725, 'y': 479, 'w': 86, 'h': 99, 'class': 3, 'class_name': 'You'}
#
# {'x': 725, 'y': 479, 'w': 86, 'h': 99, 'class': 3, 'class_name': 'You'}
#
# {'x': 725, 'y': 479, 'w': 86, 'h': 99, 'class': 3, 'class_name': 'You'}
#
# {'x': 736, 'y': 450, 'w': 74, 'h': 108, 'class': 3, 'class_name': 'You'}
#
# {'x': 729, 'y': 474, 'w': 81, 'h': 107, 'class': 3, 'class_name': 'You'}
#
# {'x': 726, 'y': 483, 'w': 86, 'h': 101, 'class': 3, 'class_name': 'You'}
#
# {'x': 726, 'y': 481, 'w': 84, 'h': 99, 'class': 3, 'class_name': 'You'}
#
# {'x': 726, 'y': 480, 'w': 85, 'h': 99, 'class': 3, 'class_name': 'You'}
#
# {'x': 722, 'y': 477, 'w': 87, 'h': 101, 'class': 3, 'class_name': 'You'}
#
# {'x': 709, 'y': 483, 'w': 66, 'h': 92, 'class': 3, 'class_name': 'You'}
#
#
#
#
#
#
#
#
#
# {'x': 556, 'y': 481, 'w': 86, 'h': 59, 'class': 2, 'class_name': 'Spider'}
#
#
# {'x': 329, 'y': 549, 'w': 70, 'h': 65, 'class': 2, 'class_name': 'Spider'}
#
# {'x': 279, 'y': 618, 'w': 70, 'h': 64, 'class': 2, 'class_name': 'Spider'}
#
#
#
# {'x': 346, 'y': 677, 'w': 93, 'h': 63, 'class': 2, 'class_name': 'Spider'}
#
# {'x': 380, 'y': 673, 'w': 80, 'h': 71, 'class': 2, 'class_name': 'Spider'}
#
# {'x': 408, 'y': 685, 'w': 79, 'h': 82, 'class': 2, 'class_name': 'Spider'}
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# {'x': 632, 'y': 480, 'w': 71, 'h': 95, 'class': 3, 'class_name': 'You'}
#
# {'x': 593, 'y': 480, 'w': 99, 'h': 98, 'class': 3, 'class_name': 'You'}
#
# {'x': 558, 'y': 480, 'w': 92, 'h': 122, 'class': 3, 'class_name': 'You'}
#
# {'x': 520, 'y': 490, 'w': 91, 'h': 171, 'class': 3, 'class_name': 'You'}
#
# {'x': 498, 'y': 536, 'w': 87, 'h': 122, 'class': 3, 'class_name': 'You'}
#
# {'x': 494, 'y': 575, 'w': 92, 'h': 116, 'class': 3, 'class_name': 'You'}
#
# {'x': 497, 'y': 606, 'w': 84, 'h': 114, 'class': 3, 'class_name': 'You'}
#
# {'x': 501, 'y': 630, 'w': 84, 'h': 103, 'class': 3, 'class_name': 'You'}
#
# {'x': 472, 'y': 558, 'w': 89, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 473, 'y': 537, 'w': 83, 'h': 93, 'class': 3, 'class_name': 'You'}
#
# {'x': 473, 'y': 528, 'w': 86, 'h': 102, 'class': 3, 'class_name': 'You'}
#
# {'x': 472, 'y': 515, 'w': 90, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 470, 'y': 508, 'w': 91, 'h': 112, 'class': 3, 'class_name': 'You'}
#
# {'x': 472, 'y': 508, 'w': 91, 'h': 105, 'class': 3, 'class_name': 'You'}
#
# {'x': 472, 'y': 497, 'w': 87, 'h': 112, 'class': 3, 'class_name': 'You'}
#
# {'x': 469, 'y': 502, 'w': 94, 'h': 116, 'class': 3, 'class_name': 'You'}
#
# {'x': 469, 'y': 503, 'w': 94, 'h': 103, 'class': 3, 'class_name': 'You'}
# {'x': 1339, 'y': 841, 'w': 70, 'h': 12, 'class': 2, 'class_name': 'Spider'}
#
# {'x': 468, 'y': 503, 'w': 93, 'h': 102, 'class': 3, 'class_name': 'You'}
#
# {'x': 475, 'y': 505, 'w': 81, 'h': 110, 'class': 3, 'class_name': 'You'}
#
# {'x': 468, 'y': 499, 'w': 88, 'h': 103, 'class': 3, 'class_name': 'You'}
#
# {'x': 471, 'y': 488, 'w': 88, 'h': 107, 'class': 3, 'class_name': 'You'}
#
# {'x': 468, 'y': 469, 'w': 91, 'h': 106, 'class': 3, 'class_name': 'You'}
#
# {'x': 470, 'y': 460, 'w': 89, 'h': 105, 'class': 3, 'class_name': 'You'}
#
# {'x': 471, 'y': 450, 'w': 89, 'h': 112, 'class': 3, 'class_name': 'You'}
#
# {'x': 474, 'y': 447, 'w': 89, 'h': 110, 'class': 3, 'class_name': 'You'}
#
# {'x': 468, 'y': 449, 'w': 94, 'h': 106, 'class': 3, 'class_name': 'You'}
#
# {'x': 472, 'y': 450, 'w': 85, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 471, 'y': 449, 'w': 89, 'h': 110, 'class': 3, 'class_name': 'You'}
#
# {'x': 470, 'y': 447, 'w': 88, 'h': 108, 'class': 3, 'class_name': 'You'}
#
# {'x': 477, 'y': 448, 'w': 80, 'h': 104, 'class': 3, 'class_name': 'You'}
#
# {'x': 474, 'y': 446, 'w': 85, 'h': 100, 'class': 3, 'class_name': 'You'}
#
# {'x': 472, 'y': 441, 'w': 86, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 475, 'y': 443, 'w': 84, 'h': 113, 'class': 3, 'class_name': 'You'}
#
# {'x': 475, 'y': 447, 'w': 81, 'h': 115, 'class': 3, 'class_name': 'You'}
#
# {'x': 477, 'y': 459, 'w': 81, 'h': 119, 'class': 3, 'class_name': 'You'}
#
# {'x': 473, 'y': 469, 'w': 87, 'h': 117, 'class': 3, 'class_name': 'You'}
#
# {'x': 473, 'y': 470, 'w': 87, 'h': 116, 'class': 3, 'class_name': 'You'}
#
# {'x': 473, 'y': 470, 'w': 88, 'h': 117, 'class': 3, 'class_name': 'You'}
#
# {'x': 473, 'y': 470, 'w': 88, 'h': 117, 'class': 3, 'class_name': 'You'}
#
# {'x': 491, 'y': 426, 'w': 85, 'h': 112, 'class': 3, 'class_name': 'You'}
#
# {'x': 520, 'y': 419, 'w': 92, 'h': 112, 'class': 3, 'class_name': 'You'}
#
# {'x': 543, 'y': 442, 'w': 95, 'h': 115, 'class': 3, 'class_name': 'You'}
#
# {'x': 577, 'y': 469, 'w': 83, 'h': 117, 'class': 3, 'class_name': 'You'}
#
# {'x': 602, 'y': 503, 'w': 92, 'h': 116, 'class': 3, 'class_name': 'You'}
#
# {'x': 634, 'y': 530, 'w': 88, 'h': 112, 'class': 3, 'class_name': 'You'}
#
# {'x': 655, 'y': 512, 'w': 84, 'h': 107, 'class': 3, 'class_name': 'You'}
#
# {'x': 683, 'y': 489, 'w': 89, 'h': 102, 'class': 3, 'class_name': 'You'}
#
# {'x': 713, 'y': 474, 'w': 89, 'h': 112, 'class': 3, 'class_name': 'You'}
#
# {'x': 741, 'y': 469, 'w': 102, 'h': 118, 'class': 3, 'class_name': 'You'}
#
# {'x': 768, 'y': 448, 'w': 101, 'h': 119, 'class': 3, 'class_name': 'You'}
#
# {'x': 801, 'y': 429, 'w': 92, 'h': 108, 'class': 3, 'class_name': 'You'}
#
# {'x': 826, 'y': 442, 'w': 94, 'h': 107, 'class': 3, 'class_name': 'You'}
#
# {'x': 851, 'y': 462, 'w': 93, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 879, 'y': 491, 'w': 95, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 903, 'y': 511, 'w': 91, 'h': 119, 'class': 3, 'class_name': 'You'}
#
# {'x': 923, 'y': 548, 'w': 95, 'h': 117, 'class': 3, 'class_name': 'You'}
#
# {'x': 937, 'y': 576, 'w': 94, 'h': 124, 'class': 3, 'class_name': 'You'}
#
# {'x': 947, 'y': 605, 'w': 85, 'h': 109, 'class': 3, 'class_name': 'You'}
#
# {'x': 941, 'y': 507, 'w': 95, 'h': 129, 'class': 3, 'class_name': 'You'}
#
# {'x': 946, 'y': 449, 'w': 96, 'h': 131, 'class': 3, 'class_name': 'You'}
#
# {'x': 947, 'y': 438, 'w': 97, 'h': 120, 'class': 3, 'class_name': 'You'}
#
# {'x': 954, 'y': 446, 'w': 93, 'h': 115, 'class': 3, 'class_name': 'You'}
#
# {'x': 944, 'y': 471, 'w': 103, 'h': 121, 'class': 3, 'class_name': 'You'}
# {'x': 1457, 'y': 314, 'w': 68, 'h': 62, 'class': 2, 'class_name': 'Spider'}
#
# {'x': 1424, 'y': 304, 'w': 93, 'h': 59, 'class': 2, 'class_name': 'Spider'}
# {'x': 948, 'y': 497, 'w': 89, 'h': 118, 'class': 3, 'class_name': 'You'}
#
# {'x': 937, 'y': 532, 'w': 74, 'h': 123, 'class': 3, 'class_name': 'You'}
# {'x': 1404, 'y': 271, 'w': 89, 'h': 59, 'class': 2, 'class_name': 'Spider'}
#
# {'x': 1388, 'y': 213, 'w': 89, 'h': 58, 'class': 2, 'class_name': 'Spider'}
# {'x': 925, 'y': 561, 'w': 83, 'h': 119, 'class': 3, 'class_name': 'You'}
#
# {'x': 1378, 'y': 149, 'w': 91, 'h': 58, 'class': 2, 'class_name': 'Spider'}
# {'x': 932, 'y': 589, 'w': 86, 'h': 112, 'class': 3, 'class_name': 'You'}
#
# {'x': 938, 'y': 562, 'w': 94, 'h': 101, 'class': 3, 'class_name': 'You'}
# {'x': 1360, 'y': 67, 'w': 86, 'h': 65, 'class': 2, 'class_name': 'Spider'}
#
# {'x': 1335, 'y': 26, 'w': 92, 'h': 58, 'class': 2, 'class_name': 'Spider'}
# {'x': 948, 'y': 514, 'w': 89, 'h': 100, 'class': 3, 'class_name': 'You'}
#
# {'x': 947, 'y': 496, 'w': 90, 'h': 105, 'class': 3, 'class_name': 'You'}
# {'x': 1311, 'y': 6, 'w': 89, 'h': 58, 'class': 2, 'class_name': 'Spider'}
#
# {'x': 947, 'y': 479, 'w': 97, 'h': 111, 'class': 3, 'class_name': 'You'}
# {'x': 1279, 'y': 1, 'w': 98, 'h': 49, 'class': 2, 'class_name': 'Spider'}
#
# {'x': 942, 'y': 483, 'w': 104, 'h': 104, 'class': 3, 'class_name': 'You'}
# {'x': 1261, 'y': 0, 'w': 97, 'h': 46, 'class': 2, 'class_name': 'Spider'}
#
# {'x': 946, 'y': 477, 'w': 99, 'h': 102, 'class': 3, 'class_name': 'You'}
# {'x': 1228, 'y': 0, 'w': 100, 'h': 40, 'class': 2, 'class_name': 'Spider'}
#
# {'x': 945, 'y': 477, 'w': 98, 'h': 100, 'class': 3, 'class_name': 'You'}
# {'x': 1204, 'y': 0, 'w': 99, 'h': 42, 'class': 2, 'class_name': 'Spider'}
#
# {'x': 952, 'y': 485, 'w': 92, 'h': 91, 'class': 3, 'class_name': 'You'}
# {'x': 1172, 'y': 0, 'w': 102, 'h': 40, 'class': 2, 'class_name': 'Spider'}
#
# {'x': 957, 'y': 487, 'w': 93, 'h': 100, 'class': 3, 'class_name': 'You'}
# {'x': 1143, 'y': 1, 'w': 99, 'h': 39, 'class': 2, 'class_name': 'Spider'}
#
# {'x': 941, 'y': 499, 'w': 91, 'h': 110, 'class': 3, 'class_name': 'You'}
#
# {'x': 929, 'y': 520, 'w': 90, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 918, 'y': 545, 'w': 92, 'h': 118, 'class': 3, 'class_name': 'You'}
#
# {'x': 908, 'y': 581, 'w': 104, 'h': 113, 'class': 3, 'class_name': 'You'}
#
# {'x': 921, 'y': 546, 'w': 95, 'h': 104, 'class': 3, 'class_name': 'You'}
#
# {'x': 933, 'y': 511, 'w': 96, 'h': 103, 'class': 3, 'class_name': 'You'}
#
# {'x': 939, 'y': 484, 'w': 101, 'h': 111, 'class': 3, 'class_name': 'You'}
#
# {'x': 942, 'y': 476, 'w': 96, 'h': 110, 'class': 3, 'class_name': 'You'}
#
# {'x': 944, 'y': 429, 'w': 100, 'h': 120, 'class': 3, 'class_name': 'You'}
#
# {'x': 950, 'y': 411, 'w': 99, 'h': 118, 'class': 3, 'class_name': 'You'}
#
# {'x': 946, 'y': 414, 'w': 94, 'h': 120, 'class': 3, 'class_name': 'You'}
#
# {'x': 945, 'y': 440, 'w': 96, 'h': 117, 'class': 3, 'class_name': 'You'}
#
# {'x': 945, 'y': 469, 'w': 96, 'h': 123, 'class': 3, 'class_name': 'You'}
#
# {'x': 913, 'y': 500, 'w': 102, 'h': 120, 'class': 3, 'class_name': 'You'}
#
# {'x': 890, 'y': 528, 'w': 105, 'h': 116, 'class': 3, 'class_name': 'You'}
#
# {'x': 887, 'y': 564, 'w': 96, 'h': 115, 'class': 3, 'class_name': 'You'}
#
# {'x': 902, 'y': 594, 'w': 86, 'h': 110, 'class': 3, 'class_name': 'You'}
#
# {'x': 907, 'y': 542, 'w': 84, 'h': 109, 'class': 3, 'class_name': 'You'}
